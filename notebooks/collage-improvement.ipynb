# %% [markdown]
# # Testing

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
malign_tumour = cv2.imread('../pipeline_data_tcia/benign/benign1.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(malign_tumour)

# %%
malign_mask = cv2.imread('../pipeline_data_tcia/benign/benign1_mask.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(malign_mask)

# %%
masked = malign_tumour.copy()
masked[malign_mask == 0] = 0
plt.imshow(masked)

# %%
masked2 = masked.copy()
masked2.shape
# Out:
# (2457, 1996)

# %%
for i in range(len(masked2)):
    for j in range(len(masked2[i])):
        if masked2[i][j] <= 50:
            masked2[i][j] = 0

# %%
plt.imshow(masked2)

# %%
cv2.imwrite("test.png", masked2)
# Out:
# True

# %%
masked2_mask = masked2.copy()
for i in range(len(masked2_mask)):
    for j in range(len(masked2_mask[i])):
        if masked2_mask[i][j] > 0:
            masked2_mask[i][j] = 1

# %%
plt.imshow(masked2_mask)

# %% [markdown]
# # Trying New Collage

# %%
# Required imports
import sys
sys.path.append("../")
import os
from utils.utils import is_collage_possible, make_collage, make_3_channels_mask

# %%
# Checks if collage is possible between two images
w, h = is_collage_possible(malign_mask_pth='../pipeline_data_tcia/malign/malign2_mask.png', normal_breast_pth='../pipeline_data_tcia/normal/normal.png')
w, h
# Out:
# (1048, 917)

# %%
make_collage(malign_pth='../pipeline_data_tcia/malign/malign2.png',malign_mask_pth='../pipeline_data_tcia/malign/malign2_mask.png',normal_pth='../pipeline_data_tcia/normal/normal.png',width=w,height=h)

# %%
# Make the collage mask 3-channel
make_3_channels_mask('collage_mask.png', 'collage_mask3.png')
os.remove('collage_mask.png')
os.rename('collage_mask3.png', 'collage_mask.png')

# %% [markdown]
# # Collage In Reduced Image Sizes

# %%
import sys
import cv2
import matplotlib.pyplot as plt
sys.path.append("../")
from utils.utils import perform_collage

# %%
base_image = "gen_sample_1.jpg"
malign = "../pipeline_data_tcia/malign/malign2.png"
malign_mask = "../pipeline_data_tcia/malign/malign2_mask.png"

# %%
perform_collage(base_image, malign, malign_mask)
# Out:
# 1
